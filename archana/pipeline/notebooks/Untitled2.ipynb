# %%
import pandas as pd

# %%
import os

# %%
os.chdir(os.getcwd().replace('pipeline/notebooks', ''))

# %%
# %pwd
# Out:
# '/Users/maayanlab/Library/Mobile Documents/com~apple~CloudDocs/Documents/Projects/analysis-pipelines/archana'

# %%
import glob
infiles = glob.glob('s1-expression.dir/ensembl/*')

# %%
for infile in infiles:
    print(infile)
    df = pd.read_table(infile, index_col='gene_symbol')
    print(df.sum()/10**6)
# Out:
# s1-expression.dir/ensembl/primary-ensembl.txt
# BBZ    216.109646
# BEL    591.168041
# BEQ    206.753241
# BFH    317.524236
# BGX    299.664842
# BJW    301.247892
# BKK    302.405793
# BMS    319.027851
# BNT    395.673450
# BNW    290.432667
# BPY    209.581723
# BQZ    291.754522
# CCI    305.637839
# CCQ    237.785650
# CDS    261.689946
# CFV    203.354227
# CGE    351.793293
# CHH    358.979828
# CHX    364.579580
# CKA    271.205020
# dtype: float64
# s1-expression.dir/ensembl/exon-ensembl.txt
# BBZ    3125.797335
# BEL    8735.031224
# BEQ    2937.313230
# BFH    4584.123577
# BGX    4283.930553
# BJW    4510.145566
# BKK    4395.710590
# BMS    4685.910923
# BNT    5648.766457
# BNW    4238.240921
# BPY    2984.116967
# BQZ    3803.358767
# CCI    4289.685551
# CCQ    3368.032862
# CDS    3700.420396
# CFV    2885.034890
# CGE    4983.747395
# CHH    5013.492923
# CHX    5086.227602
# CKA    3787.144595
# dtype: float64
# s1-expression.dir/ensembl/exon.geneID-ensembl.txt
# ...

# %%
df.head()
# Out:
#   gene_symbol       BBZ       BEL       BEQ       BFH       BGX       BJW  \
# 0        A1BG  0.000000  0.076419  0.000000  0.000000  0.000000  0.055274
# 1    A1BG-AS1  0.000000  0.076419  0.000000  0.000000  0.000000  0.104301
# 2        A1CF  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3         A2M  1.638196  1.963795  1.545423  1.870847  1.727944  1.792933
# 4     A2M-AS1  0.224487  0.382175  0.188731  0.248298  0.136244  0.055274
#
#         BKK       BMS       BNT    ...          BPY       BQZ       CCI  \
# 0  0.050101  0.087388  0.116582    ...     0.074787  0.000000  0.047351
# 1  0.095015  0.087388  0.000000    ...     0.074787  0.104230  0.047351
# 2  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 3  1.859069  1.769673  1.843665    ...     1.851830  1.729344  1.603866
# 4  0.095015  0.087388  0.149393    ...     0.138567  0.224823  0.256808
#
#         CCQ       CDS       CFV       CGE       CHH       CHX       CKA
# ...
